# %%
print("Hello World");
# Out:
# Hello World

# %%
print("Hello World");
# Out:
# Hello World

# %% [markdown]
# Python second program

# %%
print("*"*3)
# Out:
# ***

# %%
print("*")
print("*")
print("*")
# Out:
# *
# *
# *

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
name="Sanjana"
print(name)
# Out:
# Sanjana
